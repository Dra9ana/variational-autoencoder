# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from mpl_toolkits.axes_grid1 import ImageGrid
from torchvision.utils import save_image, make_grid

# %%
# create a transofrm to apply to each datapoint
transform = transforms.Compose([transforms.ToTensor()])

# download the MNIST datasets
path = '~/datasets'
train_dataset = MNIST(path, transform=transform, download=True,train = True)
test_dataset  = MNIST(path, transform=transform, download=True, train = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/datasets/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 108491301.91it/s]
# Extracting /root/datasets/MNIST/raw/train-images-idx3-ubyte.gz to /root/datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/datasets/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 21516109.03it/s]
# Extracting /root/datasets/MNIST/raw/train-labels-idx1-ubyte.gz to /root/datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/datasets/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 32714563.30it/s]
# Extracting /root/datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3466253.41it/s]
# Extracting /root/datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/datasets/MNIST/raw

# %%
# load data and setup device
batch_size = 100
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
total = 0
for train_x in train_loader:
     total += (train_x[0].size())[0]
print(total)
# Out:
# 60000

# %%
# examples of input images
dataiter = iter(train_loader)
# returns tuple of images and labels in current batch
current_batch = next(dataiter)
print(current_batch[0].shape)#(n_samples, n_channels, h, w)
print(current_batch[1].size())
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])

# %%
images = current_batch[0]
fig,axs = plt.subplots(nrows = 4, ncols = 4,figsize = (16,16))
ax = axs.ravel()
for i in range(0,16):
        image = images[i,:,:,:]
        n_channels, height, width = image.shape
        image = image.reshape(height, width,n_channels)
        ax[i].imshow(image, vmin = 0, vmax = 1, cmap = 'gray')
        ax[i].axis('off')

# %%
class VAE(nn.Module):

    def __init__(self, input_dim=28, n_channels = [1,32,64], latent_dim=100, n_distribution = 3, device=device):# jel dovoljno ovde device
        super(VAE, self).__init__()

        # hyperparams
        self.n_channels = n_channels;
        self.latent_dim = latent_dim
        self.n_distribution = n_distribution
        self.input_dim = 28
        # encoder
        self.encoder = self.encoder_model()

        # latent mean and variance
        self.latent_mean = self.mean_layer()
        self.latent_logvar = self.log_var_layer()

        # decoder
        self.decoder_dense, self.decoder_conv = self.decoder_model()

    def encoder_model(self):
        flatten_dim = self.input_dim//4
        model = nn.Sequential(
        torch.nn.Conv2d(in_channels = self.n_channels[0], out_channels =  self.n_channels[1], kernel_size = (3,3),  stride = 2,padding = 1,device = device),
        torch.nn.ReLU(),
        torch.nn.Conv2d(in_channels =  self.n_channels[1], out_channels =  self.n_channels[2], kernel_size = (3,3),  stride = 2,padding = 1,device = device),
        torch.nn.ReLU(),
        torch.nn.Flatten(),
        torch.nn.Linear(in_features = flatten_dim*flatten_dim*self.n_channels[2],out_features = self.latent_dim, device = device),
        torch.nn.ReLU()
        )
        return model
    def mean_layer(self):
        return torch.nn.Linear(in_features = self.latent_dim, out_features = self.n_distribution, device = device)

    def log_var_layer(self):
        return torch.nn.Linear(in_features = self.latent_dim, out_features = self.n_distribution,device = device)

    def decoder_model(self):
        flatten_dim = self.input_dim//4;
        model_dense = nn.Sequential(
        torch.nn.Linear(in_features = self.n_distribution,out_features = flatten_dim*flatten_dim*self.n_channels[2], device = device),
        torch.nn.ReLU())

        model_conv = nn.Sequential(
        torch.nn.ConvTranspose2d( in_channels =self.n_channels[2], out_channels =self.n_channels[2], kernel_size = (3,3), stride = 2, padding = 1, output_padding = 1, device = device),
        torch.nn.ReLU(),
        torch.nn.ConvTranspose2d(in_channels = self.n_channels[2], out_channels = self.n_channels[1], kernel_size = (3,3),  stride = 2, padding = 1,output_padding = 1,device = device),
        torch.nn.ReLU(),
        torch.nn.ConvTranspose2d(in_channels = self.n_channels[1], out_channels = self.n_channels[0], kernel_size = (3,3),padding = 1,device = device),
        torch.nn.Sigmoid()
        )
        return (model_dense, model_conv)

    def encode(self, x):
        x = self.encoder(x)
        mean =  self.latent_mean(x)
        log_var = self.latent_logvar(x)
        return mean, log_var

    def reparameterization(self, mean, log_var):
        epsilon = torch.randn_like(log_var).to(device)
        z = mean + ((0.5*log_var).exp())*epsilon
        return z

    def decode(self, x):
        x = self.decoder_dense(x);
        flatten_dim = self.input_dim//4;
        x = x.view((-1,self.n_channels[2],flatten_dim, flatten_dim))
        x = self.decoder_conv(x)
        return x

    def forward(self, x):
        mean, logvar = self.encode(x)
        z = self.reparameterization(mean, logvar)
        x_hat = self.decode(z)
        return x_hat, mean, logvar
    def reconstruction_loss(self,x,x_hat):
        return torch.sum(torch.sum(nn.functional.binary_cross_entropy(x_hat, x,reduction = 'none'), dim = (1,2,3)))#mean
        #bce_loss = nn.BCELoss()
        #return bce_loss(x_hat, x)

    def KL_loss(self,mean, log_var):
        return torch.sum(- 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp(), dim = 1), dim = 0)#mean
    def loss_function(self,x, x_hat, mean, log_var):
        beta = 1;
        reconstruction = self.reconstruction_loss(x,x_hat)
        KLD = self.KL_loss(mean, log_var)
        return reconstruction + beta*KLD

# %%
model = VAE().to(device)
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)

# %%
from torchsummary import summary
summary(model.encoder_model(),(1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 14, 14]             320
#               ReLU-2           [-1, 32, 14, 14]               0
#             Conv2d-3             [-1, 64, 7, 7]          18,496
#               ReLU-4             [-1, 64, 7, 7]               0
#            Flatten-5                 [-1, 3136]               0
#             Linear-6                  [-1, 100]         313,700
#               ReLU-7                  [-1, 100]               0
# ================================================================
# Total params: 332,516
# Trainable params: 332,516
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 1.27
# Estimated Total Size (MB): 1.44
# ----------------------------------------------------------------

# %%
summary(model.decoder_model()[0],(1,3))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1              [-1, 1, 3136]          12,544
#               ReLU-2              [-1, 1, 3136]               0
# ================================================================
# Total params: 12,544
# Trainable params: 12,544
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.10
# ----------------------------------------------------------------

# %%
summary(model.decoder_model()[1],(64,7,7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1           [-1, 64, 14, 14]          36,928
#               ReLU-2           [-1, 64, 14, 14]               0
#    ConvTranspose2d-3           [-1, 32, 28, 28]          18,464
#               ReLU-4           [-1, 32, 28, 28]               0
#    ConvTranspose2d-5            [-1, 1, 28, 28]             289
#            Sigmoid-6            [-1, 1, 28, 28]               0
# ================================================================
# Total params: 55,681
# Trainable params: 55,681
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.59
# Params size (MB): 0.21
# Estimated Total Size (MB): 0.81
# ----------------------------------------------------------------

# %% [markdown]
# Rezultati za 3D

# %%
def train(model, optimizer, epochs, device):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        total_KL_loss = 0;
        total_reconstruction_loss = 0;
        total_samples = 0;
        for batch_idx, (x, _) in enumerate(train_loader):
            #x_dim = (batch_size,1,28,28)
            #print(x.size())
            x = x.to(device)
            optimizer.zero_grad()
            x_hat, mean, log_var = model(x)

            reconstruction_loss = model.reconstruction_loss(x,x_hat)
            KL_loss = model.KL_loss(mean, log_var)
            loss = KL_loss+reconstruction_loss

            total_reconstruction_loss += reconstruction_loss.item()
            total_KL_loss += KL_loss.item()
            total_loss += loss.item()
            total_samples+=(x.size()[0])
            loss.backward()
            optimizer.step()

        print("\tEpoch", epoch + 1, "\tAverage total loss: ", total_loss/(total_samples),"\tAverage reconstruction Loss: ", total_reconstruction_loss/(total_samples),"\tAverage KL Loss: ", total_KL_loss/(total_samples))
        plt.plot(epoch+1,total_loss/(total_samples),'r*')
        plt.plot(epoch+1,total_reconstruction_loss/(total_samples),'g*')
        plt.plot(epoch+1,total_KL_loss/(total_samples),'b*')
    plt.legend(['total loss', 'reconstruction loss','KL loss'])
    plt.title('Training curve')
    plt.show()
    return total_loss/(total_samples)

train(model, optimizer, epochs=100, device=device)
# Out:
# 	Epoch 1 	Average total loss:  161.26545896809895 	Average reconstruction Loss:  154.09885419921875 	Average KL Loss:  7.166604791259766
# 	Epoch 2 	Average total loss:  154.15948631184895 	Average reconstruction Loss:  146.6877894856771 	Average KL Loss:  7.4716968292236325
# 	Epoch 3 	Average total loss:  150.56471731770833 	Average reconstruction Loss:  142.94267736002604 	Average KL Loss:  7.622039972941081
# 	Epoch 4 	Average total loss:  148.59763492838542 	Average reconstruction Loss:  140.8800619140625 	Average KL Loss:  7.7175728190104165
# 	Epoch 5 	Average total loss:  147.1503361328125 	Average reconstruction Loss:  139.376209375 	Average KL Loss:  7.77412668762207
# 	Epoch 6 	Average total loss:  146.0508251139323 	Average reconstruction Loss:  138.2075052408854 	Average KL Loss:  7.843319777425131
# 	Epoch 7 	Average total loss:  145.08761095377605 	Average reconstruction Loss:  137.21653857421876 	Average KL Loss:  7.871072494506836
# 	Epoch 8 	Average total loss:  144.28811264648436 	Average reconstruction Loss:  136.39026634114583 	Average KL Loss:  7.89784638671875
# 	Epoch 9 	Average total loss:  143.5260273111979 	Average reconstruction Loss:  135.58702504882814 	Average KL Loss:  7.939002560424805
# 	Epoch 10 	Average total loss:  142.93027421875 	Average reconstruction Loss:  134.94235693359374 	Average KL Loss:  7.987917637125651
# 	Epoch 11 	Average total loss:  142.40792241210937 	Average reconstruction Loss:  134.40326931966146 	Average KL Loss:  8.004653168741863
# 	Epoch 12 	Average total loss:  141.92827972005207 	Average reconstruction Loss:  133.88048616536457 	Average KL Loss:  8.04779369913737
# 	Epoch 13 	Average total loss:  141.37185493164063 	Average reconstruction Loss:  133.30674773763022 	Average KL Loss:  8.065107282511393
# 	Epoch 14 	Average total loss:  141.07516534830728 	Average reconstruction Loss:  132.9704712402344 	Average KL Loss:  8.104693865966796
# 	Epoch 15 	Average total loss:  140.57105764973957 	Average reconstruction Loss:  132.46432119140624 	Average KL Loss:  8.106736322021485
# 	Epoch 16 	Average total loss:  140.27062290039063 	Average reconstruction Loss:  132.1287823079427 	Average KL Loss:  8.141840357462565
# 	Epoch 17 	Average total loss:  139.8822984049479 	Average reconstruction Loss:  131.71397950846355 	Average KL Loss:  8.168318739827473
# 	Epoch 18 	Average total loss:  139.60851708984376 	Average reconstruction Loss:  131.41747088216147 	Average KL Loss:  8.191046162923177
# 	Epoch 19 	Average total loss:  139.3892940592448 	Average reconstruction Loss:  131.19070048828124 	Average KL Loss:  8.198593897501627
# 	Epoch 20 	Average total loss:  139.07771500651043 	Average reconstruction Loss:  130.8628611328125 	Average KL Loss:  8.214853772989908
# 	Epoch 21 	Average total loss:  138.79984261067708 	Average reconstruction Loss:  130.55932268880207 	Average KL Loss:  8.240520290120443
# 	Epoch 22 	Average total loss:  138.59224396158854 	Average reconstruction Loss:  130.33554676106772 	Average KL Loss:  8.256697022501628
# 	Epoch 23 	Average total loss:  138.36444741210937 	Average reconstruction Loss:  130.09732381184895 	Average KL Loss:  8.267123517862956
# 	Epoch 24 	Average total loss:  138.23546479492188 	Average reconstruction Loss:  129.91756499023438 	Average KL Loss:  8.317899498494466
# 	Epoch 25 	Average total loss:  138.04224501953124 	Average reconstruction Loss:  129.73920636393228 	Average KL Loss:  8.303038364664713
# 	Epoch 26 	Average total loss:  137.83418671875 	Average reconstruction Loss:  129.50632200520835 	Average KL Loss:  8.327864743041992
# 	Epoch 27 	Average total loss:  137.61785431315104 	Average reconstruction Loss:  129.2868256184896 	Average KL Loss:  8.331028694661459
# 	Epoch 28 	Average total loss:  137.4267161621094 	Average reconstruction Loss:  129.07685911458333 	Average KL Loss:  8.349857295735678
# 	Epoch 29 	Average total loss:  137.3318819498698 	Average reconstruction Loss:  128.96426598307292 	Average KL Loss:  8.367615590413411
# 	Epoch 30 	Average total loss:  137.15630598958333 	Average reconstruction Loss:  128.78342556966146 	Average KL Loss:  8.372880103556316
# 	Epoch 31 	Average total loss:  137.03132350260415 	Average reconstruction Loss:  128.6462755533854 	Average KL Loss:  8.385047893269856
# 	Epoch 32 	Average total loss:  136.84937991536458 	Average reconstruction Loss:  128.4618337076823 	Average KL Loss:  8.387546506754557
# 	Epoch 33 	Average total loss:  136.75361936848958 	Average reconstruction Loss:  128.3518120768229 	Average KL Loss:  8.401807315063477
# 	Epoch 34 	Average total loss:  136.59532446289063 	Average reconstruction Loss:  128.18111988932293 	Average KL Loss:  8.414204535929361
# 	Epoch 35 	Average total loss:  136.43207063802083 	Average reconstruction Loss:  128.00803912760418 	Average KL Loss:  8.42403139444987
# 	Epoch 36 	Average total loss:  136.34795152994792 	Average reconstruction Loss:  127.9290155436198 	Average KL Loss:  8.418935936482747
# 	Epoch 37 	Average total loss:  136.23711557617187 	Average reconstruction Loss:  127.79024456380208 	Average KL Loss:  8.4468711324056
# 	Epoch 38 	Average total loss:  136.12365610351563 	Average reconstruction Loss:  127.67657099609374 	Average KL Loss:  8.447084770711262
# 	Epoch 39 	Average total loss:  135.99294083658853 	Average reconstruction Loss:  127.53155538736979 	Average KL Loss:  8.46138563639323
# 	Epoch 40 	Average total loss:  135.87025476888022 	Average reconstruction Loss:  127.40523388671875 	Average KL Loss:  8.465020725504557
# 	Epoch 41 	Average total loss:  135.8240458984375 	Average reconstruction Loss:  127.3373697265625 	Average KL Loss:  8.4866760152181
# 	Epoch 42 	Average total loss:  135.69760561523438 	Average reconstruction Loss:  127.20828990885417 	Average KL Loss:  8.48931577758789
# 	Epoch 43 	Average total loss:  135.57425053710938 	Average reconstruction Loss:  127.06567166341146 	Average KL Loss:  8.50857901611328
# 	Epoch 44 	Average total loss:  135.52778435872395 	Average reconstruction Loss:  127.02566723632812 	Average KL Loss:  8.502116903686524
# 	Epoch 45 	Average total loss:  135.3909561360677 	Average reconstruction Loss:  126.8871369954427 	Average KL Loss:  8.503818931070963
# 	Epoch 46 	Average total loss:  135.32908777669272 	Average reconstruction Loss:  126.81385146484375 	Average KL Loss:  8.515236434936524
# 	Epoch 47 	Average total loss:  135.25772387695312 	Average reconstruction Loss:  126.74017560221354 	Average KL Loss:  8.517548495483398
# 	Epoch 48 	Average total loss:  135.14112796223958 	Average reconstruction Loss:  126.60183201497397 	Average KL Loss:  8.539295713297527
# 	Epoch 49 	Average total loss:  135.0774414876302 	Average reconstruction Loss:  126.53163738606771 	Average KL Loss:  8.545804467773438
# 	Epoch 50 	Average total loss:  134.9924110514323 	Average reconstruction Loss:  126.4493208984375 	Average KL Loss:  8.543090057373046
# 	Epoch 51 	Average total loss:  134.9139090332031 	Average reconstruction Loss:  126.36650830078125 	Average KL Loss:  8.547400457763672
# 	Epoch 52 	Average total loss:  134.80115911458333 	Average reconstruction Loss:  126.25405924479166 	Average KL Loss:  8.547099745686848
# 	Epoch 53 	Average total loss:  134.7995718424479 	Average reconstruction Loss:  126.22523893229166 	Average KL Loss:  8.574332944742839
# 	Epoch 54 	Average total loss:  134.66480455729166 	Average reconstruction Loss:  126.10886341145833 	Average KL Loss:  8.555941343180338
# 	Epoch 55 	Average total loss:  134.6644595703125 	Average reconstruction Loss:  126.08105388997396 	Average KL Loss:  8.583405935668946
# 	Epoch 56 	Average total loss:  134.55146931966146 	Average reconstruction Loss:  125.97989150390625 	Average KL Loss:  8.571577494303385
# 	Epoch 57 	Average total loss:  134.47923216145833 	Average reconstruction Loss:  125.89620815429687 	Average KL Loss:  8.583024007161459
# 	Epoch 58 	Average total loss:  134.41692080078124 	Average reconstruction Loss:  125.83349970703125 	Average KL Loss:  8.583421098836263
# 	Epoch 59 	Average total loss:  134.3626524576823 	Average reconstruction Loss:  125.76878678385417 	Average KL Loss:  8.59386545715332
# 	Epoch 60 	Average total loss:  134.33400452473958 	Average reconstruction Loss:  125.73153592122395 	Average KL Loss:  8.602468743896484
# 	Epoch 61 	Average total loss:  134.20849189453125 	Average reconstruction Loss:  125.60317086588542 	Average KL Loss:  8.605320897420247
# 	Epoch 62 	Average total loss:  134.1621310221354 	Average reconstruction Loss:  125.55906429036459 	Average KL Loss:  8.603066749064128
# 	Epoch 63 	Average total loss:  134.10982509765626 	Average reconstruction Loss:  125.50060841471354 	Average KL Loss:  8.609216813151042
# 	Epoch 64 	Average total loss:  134.07379049479167 	Average reconstruction Loss:  125.45817604166666 	Average KL Loss:  8.615614638264974
# 	Epoch 65 	Average total loss:  134.00688636067707 	Average reconstruction Loss:  125.37368728841146 	Average KL Loss:  8.633199322509766
# 	Epoch 66 	Average total loss:  133.9364754231771 	Average reconstruction Loss:  125.31449705403647 	Average KL Loss:  8.621978467814127
# 	Epoch 67 	Average total loss:  133.8988309407552 	Average reconstruction Loss:  125.26359059244791 	Average KL Loss:  8.635240277099609
# 	Epoch 68 	Average total loss:  133.83887958984374 	Average reconstruction Loss:  125.20101695963541 	Average KL Loss:  8.637863092041016
# 	Epoch 69 	Average total loss:  133.81836300455728 	Average reconstruction Loss:  125.16171435546875 	Average KL Loss:  8.656648720296223
# 	Epoch 70 	Average total loss:  133.7486234375 	Average reconstruction Loss:  125.09329946289063 	Average KL Loss:  8.65532417602539
# 	Epoch 71 	Average total loss:  133.70138658854168 	Average reconstruction Loss:  125.05132288411458 	Average KL Loss:  8.65006352335612
# 	Epoch 72 	Average total loss:  133.7003328125 	Average reconstruction Loss:  125.0363142578125 	Average KL Loss:  8.664018430582683
# 	Epoch 73 	Average total loss:  133.5774712076823 	Average reconstruction Loss:  124.92349217122396 	Average KL Loss:  8.653979128011068
# 	Epoch 74 	Average total loss:  133.56271059570312 	Average reconstruction Loss:  124.89547421875 	Average KL Loss:  8.667236389160156
# 	Epoch 75 	Average total loss:  133.5016575846354 	Average reconstruction Loss:  124.85406207682291 	Average KL Loss:  8.647595823160808
# 	Epoch 76 	Average total loss:  133.46889752604167 	Average reconstruction Loss:  124.80297482096354 	Average KL Loss:  8.665922592163087
# 	Epoch 77 	Average total loss:  133.4663022298177 	Average reconstruction Loss:  124.78910841471354 	Average KL Loss:  8.677194189453125
# 	Epoch 78 	Average total loss:  133.40719108072918 	Average reconstruction Loss:  124.71654093424479 	Average KL Loss:  8.690650124104817
# 	Epoch 79 	Average total loss:  133.3208966796875 	Average reconstruction Loss:  124.64965994466147 	Average KL Loss:  8.671236814371746
# 	Epoch 80 	Average total loss:  133.30082690429688 	Average reconstruction Loss:  124.62049998372396 	Average KL Loss:  8.680326951090494
# 	Epoch 81 	Average total loss:  133.30460172526043 	Average reconstruction Loss:  124.59968028971355 	Average KL Loss:  8.70492092183431
# 	Epoch 82 	Average total loss:  133.19976585286457 	Average reconstruction Loss:  124.50968914388021 	Average KL Loss:  8.690076897176107
# 	Epoch 83 	Average total loss:  133.1599328938802 	Average reconstruction Loss:  124.46750802408854 	Average KL Loss:  8.692425060017904
# 	Epoch 84 	Average total loss:  133.1372607421875 	Average reconstruction Loss:  124.43026416015626 	Average KL Loss:  8.706996664428711
# 	Epoch 85 	Average total loss:  133.14197622070313 	Average reconstruction Loss:  124.43338875325522 	Average KL Loss:  8.708587535603842
# 	Epoch 86 	Average total loss:  133.07558580729167 	Average reconstruction Loss:  124.36716100260416 	Average KL Loss:  8.708424867757161
# 	Epoch 87 	Average total loss:  133.05796630859376 	Average reconstruction Loss:  124.34432604166666 	Average KL Loss:  8.713640031941733
# 	Epoch 88 	Average total loss:  132.99629715169272 	Average reconstruction Loss:  124.27997431640625 	Average KL Loss:  8.716322600301107
# 	Epoch 89 	Average total loss:  133.02220122070312 	Average reconstruction Loss:  124.28618507486979 	Average KL Loss:  8.73601639811198
# 	Epoch 90 	Average total loss:  132.90774996744793 	Average reconstruction Loss:  124.18887094726563 	Average KL Loss:  8.718879019165039
# 	Epoch 91 	Average total loss:  132.91295857747397 	Average reconstruction Loss:  124.18821220703126 	Average KL Loss:  8.724746501668294
# 	Epoch 92 	Average total loss:  132.86313427734376 	Average reconstruction Loss:  124.12841129557292 	Average KL Loss:  8.734722932942708
# 	Epoch 93 	Average total loss:  132.8559005045573 	Average reconstruction Loss:  124.11547319335938 	Average KL Loss:  8.740427360026041
# 	Epoch 94 	Average total loss:  132.81932265625 	Average reconstruction Loss:  124.08535247395834 	Average KL Loss:  8.733970054117838
# 	Epoch 95 	Average total loss:  132.7786166829427 	Average reconstruction Loss:  124.04000966796875 	Average KL Loss:  8.738606822713216
# 	Epoch 96 	Average total loss:  132.71946388346353 	Average reconstruction Loss:  123.98481323242187 	Average KL Loss:  8.734650675455729
# 	Epoch 97 	Average total loss:  132.711509765625 	Average reconstruction Loss:  123.97307828776042 	Average KL Loss:  8.738431481933594
# 	Epoch 98 	Average total loss:  132.67610369466146 	Average reconstruction Loss:  123.9217655436198 	Average KL Loss:  8.75433819173177
# 	Epoch 99 	Average total loss:  132.6449904296875 	Average reconstruction Loss:  123.90453440755208 	Average KL Loss:  8.740456297810873
# 	Epoch 100 	Average total loss:  132.59351419270834 	Average reconstruction Loss:  123.8561290201823 	Average KL Loss:  8.737384983317057
# 132.59351419270834

# %%
n = 10
fig,axs = plt.subplots(nrows = n, ncols = n, figsize = (20,20))
for i in range(0,n):
  for j in range(0,n):
      z = torch.randn(1,3)
      x_decoded = model.decode(z)[0];
      x_decoded = x_decoded.permute(1,2,0)
      image = x_decoded.detach().numpy()
      axs[i,j].imshow(image, vmin = 0, vmax = 1, cmap = 'gray')
      axs[i,j].axis('off')

# %%
def test(model):
    total_loss = 0
    total_KL_loss = 0;
    total_reconstruction_loss = 0;
    total_samples = 0;
    for batch_idx, (x, _) in enumerate(train_loader):
            #x_dim = (batch_size,1,28,28)
            #print(x.size())
            x_hat, mean, log_var = model(x)

            reconstruction_loss = model.reconstruction_loss(x,x_hat)
            KL_loss = model.KL_loss(mean, log_var)
            loss = KL_loss+reconstruction_loss

            total_reconstruction_loss += reconstruction_loss.item()
            total_KL_loss += KL_loss.item()
            total_loss += loss.item()
            total_samples+=(x.size()[0])

    print("\tTest evaluation", "\tAverage total loss: ", total_loss/(total_samples),"\tAverage reconstruction Loss: ", total_reconstruction_loss/(total_samples),"\tAverage KL Loss: ", total_KL_loss/(total_samples))
test(model)
# Out:
# 	Test evaluation 	Average total loss:  132.3857901529948 	Average reconstruction Loss:  123.628955859375 	Average KL Loss:  8.756834337361653

# %% [markdown]
# Rezultati za 2D

# %%
torch.save(model,'model_good.pt')

# %%
def plot_latent_space(model, scale=3.0, n=50, digit_size=28, figsize=15):
    # display a n*n 2D manifold of digits
    figure = np.zeros((digit_size * n, digit_size * n))

    # construct a grid
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = torch.tensor([[xi, yi]], dtype=torch.float).to(device)
            x_decoded = model.decode(z_sample)
            digit = x_decoded[0].detach().cpu().reshape(digit_size, digit_size)
            figure[i * digit_size : (i + 1) * digit_size, j * digit_size : (j + 1) * digit_size,] = digit

    plt.figure(figsize=(figsize, figsize))
    plt.title('VAE Latent Space Visualization')
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel(" z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(model)

# %%
import matplotlib.pyplot as plt

plt.figure()
for batch_idx, (x, label) in enumerate(train_loader):
      mean, logvar = model.encode(x)
      mean = mean.detach().numpy()
      plt.scatter(mean[:, 0], mean[:, 1], c=label)
plt.colorbar()
plt.xlabel("mean[0]")
plt.ylabel("mean[1]")
plt.show()

# %%
def test(model):
    total_loss = 0
    total_KL_loss = 0;
    total_reconstruction_loss = 0;
    total_samples = 0;
    for batch_idx, (x, _) in enumerate(train_loader):
            #x_dim = (batch_size,1,28,28)
            #print(x.size())
            x_hat, mean, log_var = model(x)

            reconstruction_loss = model.reconstruction_loss(x,x_hat)
            KL_loss = model.KL_loss(mean, log_var)
            loss = KL_loss+reconstruction_loss

            total_reconstruction_loss += reconstruction_loss.item()
            total_KL_loss += KL_loss.item()
            total_loss += loss.item()
            total_samples+=(x.size()[0])

    print("\tTest evaluation", "\tAverage total loss: ", total_loss/(total_samples),"\tAverage reconstruction Loss: ", total_reconstruction_loss/(total_samples),"\tAverage KL Loss: ", total_KL_loss/(total_samples))
test(model)
# Out:
# 	Test evaluation 	Average total loss:  148.78212757161458 	Average reconstruction Loss:  142.18313984375 	Average KL Loss:  6.598987708536784

# %%
import matplotlib.pyplot as plt

plt.figure()
for batch_idx, (x, label) in enumerate(test_loader):
      mean, logvar = model.encode(x)
      mean = mean.detach().numpy()
      plt.scatter(mean[:, 0], mean[:, 1], c=label)
plt.colorbar()
plt.xlabel("mean[0]")
plt.ylabel("mean[1]")
plt.show()
